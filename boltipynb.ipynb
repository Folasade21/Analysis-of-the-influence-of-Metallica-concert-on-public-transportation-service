# %% [markdown]
# <a href="https://colab.research.google.com/github/Folasade21/Analysis-of-the-influence-of-Metallica-concert-on-public-transportation-service/blob/master/boltipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("bolt_task.csv")
data
# Out:
#        Order Created Time Order ID  Restaurant ID          Title Currency  \
# 0     2021-12-22 12:51:05      ZZW          18269  ProductBottle      eur
# 1     2021-12-22 12:51:05      ZZW          18269  ProductBottle      eur
# 2     2021-12-22 12:51:05      ZZW          18269        Deposit      eur
# 3     2021-12-26 15:27:27      ZY4          18256  ProductBottle      eur
# 4     2021-12-28 20:05:00      ZY0          18256  ProductBottle      eur
# ...                   ...      ...            ...            ...      ...
# 2559  2022-01-01 15:35:50      01W          18265  ProductBottle      eur
# 2560  2022-01-01 15:35:50      01W          18265        Deposit      eur
# 2561  2021-12-29 18:39:14      00O          18256  ProductBottle      eur
# 2562  2021-12-29 18:39:14      00O          18256  ProductBottle      eur
# 2563  2021-12-29 18:39:14      00O          18256        Deposit      eur
#
#       Quantity  Unit Price (with VAT)  Total (without VAT)  Total (with VAT)  \
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2564 entries, 0 to 2563
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order_Created_Time  2564 non-null   object
#  1   Order_ID            2564 non-null   object
#  2   Restaurant_ID       2564 non-null   int64
#  3   Title               2564 non-null   object
#  4   Currency            2564 non-null   object
#  5   Quantity            2564 non-null   int64
#  6   Unit_price_vat      2564 non-null   float64
#  7   Total               2564 non-null   float64
#  8   Total_vat           2564 non-null   float64
#  9   Bolt_Service_Fee    2564 non-null   float64
#  10  Unit_Price          2564 non-null   float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 220.5+ KB

# %%
data.columns
# Out:
# Index(['Order Created Time', 'Order ID', 'Restaurant ID', 'Title', 'Currency',
#        'Quantity', 'Unit Price (with VAT)', 'Total (without VAT)',
#        'Total (with VAT)', 'Bolt Service Fee', 'Unit Price (Without VAT)'],
#       dtype='object')

# %%
data.rename(columns = {'Order Created Time':'Order_Created_Time', 'Order ID':'Order_ID',
                              'Restaurant ID':'Restaurant_ID', 'Unit Price (with VAT)':'Unit_price_with_vat', 'Total (without VAT)':'Total_without_vat', 'Total (with VAT)':'Total_with_vat', 'Bolt Service Fee':'Bolt_Service_Fee', 'Unit Price (Without VAT)':'Unit_Price_without_vat' }, inplace = True)

# %%
data
# Out:
#        Order_Created_Time Order_ID  Restaurant_ID          Title Currency  \
# 0     2021-12-22 12:51:05      ZZW          18269  ProductBottle      eur
# 1     2021-12-22 12:51:05      ZZW          18269  ProductBottle      eur
# 2     2021-12-22 12:51:05      ZZW          18269        Deposit      eur
# 3     2021-12-26 15:27:27      ZY4          18256  ProductBottle      eur
# 4     2021-12-28 20:05:00      ZY0          18256  ProductBottle      eur
# ...                   ...      ...            ...            ...      ...
# 2559  2022-01-01 15:35:50      01W          18265  ProductBottle      eur
# 2560  2022-01-01 15:35:50      01W          18265        Deposit      eur
# 2561  2021-12-29 18:39:14      00O          18256  ProductBottle      eur
# 2562  2021-12-29 18:39:14      00O          18256  ProductBottle      eur
# 2563  2021-12-29 18:39:14      00O          18256        Deposit      eur
#
#       Quantity  Unit_price_with_vat  Total_without_vat  Total_with_vat  \
# ...

# %%
data['Restaurant_ID'].unique()
# Out:
# array([18269, 18256, 19983, 18265, 18270, 19984, 18250, 19985, 19981,
#        34221, 19982])

# %%
original_data = data.copy(deep=True) 
original_data
# Out:
#        Order_Created_Time Order_ID  Restaurant_ID          Title Currency  \
# 0     2021-12-22 12:51:05      ZZW          18269  ProductBottle      eur
# 1     2021-12-22 12:51:05      ZZW          18269  ProductBottle      eur
# 2     2021-12-22 12:51:05      ZZW          18269        Deposit      eur
# 3     2021-12-26 15:27:27      ZY4          18256  ProductBottle      eur
# 4     2021-12-28 20:05:00      ZY0          18256  ProductBottle      eur
# ...                   ...      ...            ...            ...      ...
# 2559  2022-01-01 15:35:50      01W          18265  ProductBottle      eur
# 2560  2022-01-01 15:35:50      01W          18265        Deposit      eur
# 2561  2021-12-29 18:39:14      00O          18256  ProductBottle      eur
# 2562  2021-12-29 18:39:14      00O          18256  ProductBottle      eur
# 2563  2021-12-29 18:39:14      00O          18256        Deposit      eur
#
#       Quantity  Unit_price_with_vat  Total_without_vat  Total_with_vat  \
# ...

# %%
original_data.shape
# Out:
# (2564, 11)

# %%
resturant_1=original_data[(original_data['Restaurant_ID'] == 18269)] 
resturant_1
# Out:
#        Order_Created_Time Order_ID  Restaurant_ID          Title Currency  \
# 0     2021-12-22 12:51:05      ZZW          18269  ProductBottle      eur
# 1     2021-12-22 12:51:05      ZZW          18269  ProductBottle      eur
# 2     2021-12-22 12:51:05      ZZW          18269        Deposit      eur
# 20    2021-12-25 10:38:34      ZPO          18269  ProductBottle      eur
# 21    2021-12-25 10:38:34      ZPO          18269        Deposit      eur
# 22    2021-12-25 10:38:34      ZPO          18269  ProductBottle      eur
# 23    2021-12-25 10:38:34      ZPO          18269  ProductBottle      eur
# 24    2021-12-25 10:38:34      ZPO          18269  ProductBottle      eur
# 675   2021-12-20 12:47:38      PX7          18269  ProductBottle      eur
# 676   2021-12-20 12:47:38      PX7          18269  ProductBottle      eur
# 677   2021-12-20 12:47:38      PX7          18269        Deposit      eur
# 761   2021-12-22 17:40:02      OEJ          18269  ProductBottle      eur
# ...

# %%
resturant_1.shape
# Out:
# (37, 11)

# %%
resturant_1['resturant_benefit']= resturant_1['Total_with_vat']-resturant_1['Bolt_Service_Fee']
resturant_1
# Out:
# <ipython-input-109-245624a31dd4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resturant_1['resturant_benefit']= resturant_1['Total_with_vat']-resturant_1['Bolt_Service_Fee']
#        Order_Created_Time Order_ID  Restaurant_ID          Title Currency  \
# 0     2021-12-22 12:51:05      ZZW          18269  ProductBottle      eur
# 1     2021-12-22 12:51:05      ZZW          18269  ProductBottle      eur
# 2     2021-12-22 12:51:05      ZZW          18269        Deposit      eur
# 20    2021-12-25 10:38:34      ZPO          18269  ProductBottle      eur
# 21    2021-12-25 10:38:34      ZPO          18269        Deposit      eur
# 22    2021-12-25 10:38:34      ZPO          18269  ProductBottle      eur
# ...

# %%
resturant_1['Bolt_Service_Fee'].sum()
# Out:
# 84.95

# %%
resturant_1['Total_with_vat'].sum()
# Out:
# 1019.9700000000001

# %%
benefit= resturant_1['resturant_benefit'].sum()
print('Dear bolt partner, Your total balance for this payout is' , benefit )
# Out:
# Dear bolt partner, Your total balance for this payout is 935.0200000000002

# %%
resturant_2=original_data[(original_data['Restaurant_ID'] == 18256)] 
resturant_2
# Out:
#        Order_Created_Time Order_ID  Restaurant_ID          Title Currency  \
# 3     2021-12-26 15:27:27      ZY4          18256  ProductBottle      eur
# 4     2021-12-28 20:05:00      ZY0          18256  ProductBottle      eur
# 13    2021-12-23 13:37:08      ZTO          18256  ProductBottle      eur
# 26    2021-12-24 13:52:24      ZKU          18256  ProductBottle      eur
# 27    2021-12-24 13:52:24      ZKU          18256        Deposit      eur
# ...                   ...      ...            ...            ...      ...
# 2540  2022-01-01 12:09:35      5.0          18256  ProductBottle      eur
# 2553  2021-12-19 20:25:33      02D          18256  ProductBottle      eur
# 2561  2021-12-29 18:39:14      00O          18256  ProductBottle      eur
# 2562  2021-12-29 18:39:14      00O          18256  ProductBottle      eur
# 2563  2021-12-29 18:39:14      00O          18256        Deposit      eur
#
#       Quantity  Unit_price_with_vat  Total_without_vat  Total_with_vat  \
# ...

# %%
resturant_2.shape
# Out:
# (598, 11)

# %%
resturant_3=original_data[(original_data['Restaurant_ID'] == 19983)] 
resturant_3
# Out:
#        Order_Created_Time Order_ID  Restaurant_ID          Title Currency  \
# 5     2021-12-22 20:42:22      ZU0          19983        Deposit      eur
# 6     2021-12-22 20:42:22      ZU0          19983  ProductBottle      eur
# 7     2021-12-22 20:42:22      ZU0          19983        Deposit      eur
# 8     2021-12-22 20:42:22      ZU0          19983  ProductBottle      eur
# 9     2021-12-22 20:42:22      ZU0          19983  ProductBottle      eur
# ...                   ...      ...            ...            ...      ...
# 2548  2021-12-30 19:58:47      02I          19983  ProductBottle      eur
# 2549  2021-12-30 19:58:47      02I          19983  ProductBottle      eur
# 2554  2021-12-27 11:31:04      02A          19983        Deposit      eur
# 2555  2021-12-27 11:31:04      02A          19983  ProductBottle      eur
# 2556  2021-12-27 11:31:04      02A          19983  ProductBottle      eur
#
#       Quantity  Unit_price_with_vat  Total_without_vat  Total_with_vat  \
# ...
